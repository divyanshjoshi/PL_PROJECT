# %%
import tweepy
import json
consumer_key = "NezhcZ7ZOHTFMyvKNuwdxEpb4" 
consumer_secret = "SkaBr8LQ3PNTTYXD4z1lbV886A2MT22fFmEvPNoqWRPG3nD4QE"
access_key = "1020013932403019776-tOjd5QMASut2DSegqOp3kwQiyV6m5N"
access_secret = "E4RD5jIqJqIFeHvOK82YsTZi1IXVJVEqZXK2OOAtLdaBj"

# %%
auth = tweepy.OAuthHandler(consumer_key,consumer_secret)

# %%
auth.set_access_token(access_key, access_secret)

# %%
api = tweepy.API(auth)

# %%
public_tweets = api.home_timeline()
for tweet in public_tweets:
    print(tweet.text)
# Out:
# #Nepal: Ruling Nepal Communist Party (NCP) wins 30 seats in by poll to elect 52 people’s representatives… https://t.co/oqVKEFevF3
# 'Scare-mongering about #Russia, #China, terrorism or something else amounts to excuses, not reasons, for #NATO’s co… https://t.co/C4ErDelnhd
# RT @GuggerSylvain: If you find yourself constantly copying and pasting between notebooks and python modules, this tool is made for you. We…
# RT @narendramodi: Invigorating the India-Sweden friendship with closer cooperation in innovation and technology.
#
# His Majesty King Carl XV…
# RT @narendramodi: Delighted to meet Their Majesties King Carl XVI Gustaf and Queen Silvia.
#
# We had extensive discussions on boosting coope…
# Power of #Siberia: #Russia, #China launch strategic gas pipeline
#
# DETAILS: https://t.co/lIfB4GIHrV https://t.co/zdUQY1PkaZ
# #Cabinet Secretary reviews the issue of #OnionPrices in the Country
#
# Read here: https://t.co/HgKv1EjA1L
# Lt Gen P S Rajeshwar takes over as C-n-C of Andaman &amp; Nicobar Command
#
# Read here: https://t.co/OTfofh5D7s https://t.co/ZeqDu10KVJ
# .@IncomeTaxIndia conducts searches in NCR
#
# Read here: https://t.co/VOibRaRdUv
# DM of Sitamarhi is leading from the front, as the Intensified Mission Indradhanush 2.0 campaign makes its way in th… https://t.co/mAzAfMqe3Y
# #BREAKINGonRT
#
# US to help ‘legitimate Latin American govts’ to PREVENT PROTESTS from ‘morphing into riots’ –… https://t.co/jNGNPGuT0X
# RT @RTUKnews: 'Whoever is appointed to take on the newly-advertised role of the Queen’s travel guru, one thing is certain, someone’s going…
# Listen to the Wyss' own Justin Werfel on @WevolverApp's podcast talking about programmable swarm robots.… https://t.co/xdXDJVA8g0
# #Moscow: World’s top city destination
#
# READ MORE: https://t.co/Et6UyIby1a https://t.co/BSKFx8r7U7
# It seemed like the whole MOON was falling! Remain calm, it's only a 'MINIMOON'
#
# https://t.co/2U4EglbnHL
# RT @RTSportNews: 🤸‍♀️ Gymnastics royalty @Simone_Biles with a not so casual dive into the sea!
#
# https://t.co/pkhRvkxg8p
# The #AIMtoInnovate of students from #AtalTinkeringLabs has evolved multi-fold in the last two days through collabor… https://t.co/6uSmtRRY0x
# RT @emilawad: @hseas @wyssinstitute @PNASNews @SMitragotri Incredible potential! I find the ability to collaborate between disciplines and…
# RT @RTSportNews: 👀 Leaked #BallonDor2019 Results https://t.co/Ck6tQxQmzr
# #NEET2020 application registration process for May 3, 2020 examination begins
#
# https://t.co/OnDA9IJRCg https://t.co/RxwNszqGJe

# %%
api = tweepy.API(auth)
name = "economictimes"
tweetCount = 100
results = api.user_timeline(id=name, count=tweetCount)

# %%
i=0
tweet_data={}
for tweet in results:
    print(tweet.text)
    print()
    print('Date and Time of Tweet:-')
    print(tweet.created_at) #date of tweet
    tweet_data[i]={"text":tweet.text,
                   "date":str(tweet.created_at),
                   "URL_ID":str(tweet.id),
                   "Likes":tweet.user.favourites_count,
                   "Retweet":tweet.retweet_count,
                   "Hashtags": tweet.entities['hashtags']}

    i+=1
    
    
print('Profile Name:-')
print(tweet.user.name) 
print()
print('Twitter ID:-')
print(tweet.user.screen_name)
print()
print('Bio:-')
print(tweet.user.description)
print()
print('Location:-')
print(tweet.user.location) 
print()
print('URL:-')
print(tweet.user.url) 
print()
print('Joined:-')
print(tweet.user.created_at) 
print()
print('Following:-')
print(tweet.user.friends_count)
print()
print('Followers:-')
print(tweet.user.followers_count) 
print()
print('Profile Image:-')
print(tweet.user.profile_image_url_https) 
print()
print('Coverpage:-')
print(tweet.user.profile_banner_url) 
print()
print('Verification:-')
print(tweet.user.verified) 
print()
# Out:
# Even with an announced tariff hike of 40%, #RelianceJio would be cheaper by 15-20% than other incumbents, analyst f… https://t.co/5Ol7dvPpCd
#
# Date and Time of Tweet:-
# 2019-12-02 15:35:00
# "Over 62 per cent or about $58 billion of the total loan advances ($93 billion) to Indian #RealEstate by banks and… https://t.co/sSDHQMl740
#
# Date and Time of Tweet:-
# 2019-12-02 15:33:12
# Justice Devan Ramachandran went hammer and tongs at the @vijayanpinarayi govt while taking up a contempt petition f… https://t.co/RZzuGGpL6F
#
# Date and Time of Tweet:-
# 2019-12-02 15:32:15
# #BJP MP Nishikant Dubey said in the Lok Sabha that #GDP has no relevance and it should not be treated as 'Bible, Ra… https://t.co/qP3Bhos8O1
#
# Date and Time of Tweet:-
# 2019-12-02 15:30:59
# Refuting the claim, @Dev_Fadnavis said neither the Centre asked for any funds nor the #Maharashtra government sent… https://t.co/wYYWpPtwKs
#
# Date and Time of Tweet:-
# 2019-12-02 15:30:00
# Gross direct tax collection increased by 5 per cent till November, Finance Minister #NirmalaSitharaman said on Mond… https://t.co/4zHz4neEFo
#
# Date and Time of Tweet:-
# 2019-12-02 15:27:22
# #ChandaKochhar had moved the Bombay High Court challenging #ICICIBank's decision to terminate her despite the bank… https://t.co/bTp5tt3bfS
#
# Date and Time of Tweet:-
# 2019-12-02 15:25:33
# "Madam we are neither anti national nor anti government. We want you to succeed big time as fastest growing economy… https://t.co/rkRTOf9On2
#
# Date and Time of Tweet:-
# 2019-12-02 15:24:52
# RT @ET_Wealth: #Karvy Stock Broking #scandal: How #retail #investors can safeguard against such #frauds
# #karvystockbroking #karvyscam #safe…
#
# Date and Time of Tweet:-
# 2019-12-02 15:23:33
# RT @ET_Wealth: #Compensation you get for #poorservice offered by insurers, #banks, #mutualfunds, #tax department
# #personalfinance #customer…
#
# Date and Time of Tweet:-
# 2019-12-02 15:23:28
# "At present, there is no proposal to reduce #taxes on petrol and diesel," @nsitharaman said
#
# https://t.co/drAhklD8fV
#
# Date and Time of Tweet:-
# 2019-12-02 15:15:00
# "The National Curriculum Framework (NCF), developed by the National Council of Education Research and Training (… https://t.co/swIiWHKQ8n
#
# Date and Time of Tweet:-
# 2019-12-02 15:00:00
# #India has been consistently increasing domestic production of #steel and is a net exporter in the current financia… https://t.co/8vKwoZy2El
#
# Date and Time of Tweet:-
# 2019-12-02 14:45:00
# Nearly 78 per cent depositors of the scam-hit #PMCBank have been allowed to withdraw their entire deposits even tho… https://t.co/qzBPMeNbKY
#
# Date and Time of Tweet:-
# 2019-12-02 14:30:00
# Total #motorcycle sales stood at 3,43,446 units, a marginal decline of 0.8 per cent, as compared to 3,46,544 units… https://t.co/2vhoIInAfv
#
# Date and Time of Tweet:-
# 2019-12-02 14:15:00
# Emerging #markets may need more than a surprise recovery in Chinese manufacturing to exorcise the pain of November.
#
# https://t.co/PRtjY9oub1
#
# Date and Time of Tweet:-
# 2019-12-02 14:00:00
# #Sebi's prompt action against #KarvyStockBroking has resulted in nearly 83,000 investors getting back their securit… https://t.co/hYTUqMI3x9
#
# Date and Time of Tweet:-
# 2019-12-02 13:51:30
# Uttar Pradesh govt recommended the selection of Zurich Airport International AG as the developer for the… https://t.co/Zaz9mmC9Dn
#
# Date and Time of Tweet:-
# 2019-12-02 13:49:47
# In a #SecurityBreach, seven unknown persons in a car drove up to the porch of Congress leader @priyankagandhi's Lod… https://t.co/z0xNEwgTRP
#
# Date and Time of Tweet:-
# 2019-12-02 13:45:58
# "BJP govt at the Centre and the state are grabbing money from people of the country and filling pockets of 15 peopl… https://t.co/6ROGu6SLmV
#
# Date and Time of Tweet:-
# 2019-12-02 13:45:00
# King, Queen of #Sweden meet PM #Modi, discuss ways to deepen ties https://t.co/Z17gQXFJYU https://t.co/Bt2g7A0Hxz
#
# Date and Time of Tweet:-
# 2019-12-02 13:43:01
# .@asadowaisi corners govt on #economy, in Parliament | Download the ET App here: https://t.co/OpmgPJ3iU4 https://t.co/gMtHzQrMLr
#
# Date and Time of Tweet:-
# 2019-12-02 13:42:33
# ‘#NDA is committed to save #BSNL’, says #NirmalaSitharaman in Parliament | Download the ET App here:… https://t.co/KZoAXRlAyV
#
# Date and Time of Tweet:-
# 2019-12-02 13:37:21
# 78% depositors of #PMCBank can withdraw their entire account balance: FM @nsitharaman  https://t.co/MHvj2tui7h https://t.co/MxJzQvDJab
#
# Date and Time of Tweet:-
# 2019-12-02 13:34:12
# A consumer court in Maharashtra's Jalna district has ordered a state-run bus depot to pay Rs 5,000 as compensation… https://t.co/8wNSyDdBWm
#
# Date and Time of Tweet:-
# 2019-12-02 13:30:00
# #IndianRailways operating ratio of 98.44% worst in 10 years: #CAG https://t.co/2zovwcTgo9 https://t.co/BZSODNAZJk
#
# Date and Time of Tweet:-
# 2019-12-02 13:28:21
# Rapists should be lynched: #JayaBachchan in #RajyaSabha https://t.co/z3kUYnzmpE https://t.co/9uEh0QDOxR
#
# Date and Time of Tweet:-
# 2019-12-02 13:26:52
# Swedish King, Queen accorded ceremonial reception at #RashtrapatiBhavan | Download the ET App here:… https://t.co/lsBevBWX27
#
# Date and Time of Tweet:-
# 2019-12-02 13:25:37
# RT @ET_RISE: .@Uber has a little over 1,000 employees providing critical regional and global customer support services to Uber riders, driv…
#
# Date and Time of Tweet:-
# 2019-12-02 13:15:42
# As soon as the House met for the day, Speaker Om Birla said he would allow members to raise the "serious issue" in… https://t.co/5RP93tzrpJ
#
# Date and Time of Tweet:-
# 2019-12-02 13:15:00
# RT @ET_Wealth: How long-term #investors should #deal with #market volatility
# #financialplanning #investments
# https://t.co/MoZkrRrdS8
#
# Date and Time of Tweet:-
# 2019-12-02 13:12:56
# #LeadStoryOnET | Traders want #Amazon, #Walmart to 'go back' https://t.co/NnGPnMr8so
#
# Date and Time of Tweet:-
# 2019-12-02 13:11:11
# #LeadStoryOnET | Meet the Canadian billionaire who's putting money in @YESBANK https://t.co/nDKRBSABKh
#
# Date and Time of Tweet:-
# 2019-12-02 13:10:24
# #LeadStoryOnET | Pay may go up in India, but there's a rider https://t.co/7iR2vU6cxR
#
# Date and Time of Tweet:-
# 2019-12-02 13:09:46
# Textile player #Raymond on Monday said ownership of Raymond brand will remain with the demerged new lifestyle compa… https://t.co/Q1iDHThevM
#
# Date and Time of Tweet:-
# 2019-12-02 13:00:00
# Uttar Pradesh sugar mills have to provide fixed amounts of #molasses to #AlcoholicDrinks manufacturers at well belo… https://t.co/xnwYE6nRgB
#
# Date and Time of Tweet:-
# 2019-12-02 12:45:00
# RT @ETDefence: The #IslamicState has claimed responsibility for the #LondonBridgeAttack, saying the UK-born attacker, who wanted to set up…
#
# Date and Time of Tweet:-
# 2019-12-02 12:35:30
# In Pics | Low #tariff regime over
#
# https://t.co/KZYCUsc6NL
#
# Date and Time of Tweet:-
# 2019-12-02 12:30:00
# RT @ET_Wealth: #Money &amp; #Relationships: What are woman’s #Rights in a live-in arrangement?
# #FinancialPlanning #woman
# https://t.co/A093wBI6…
#
# Date and Time of Tweet:-
# 2019-12-02 12:20:56
# RT @ET_RISE: Online marketplaces have become a go-to place as it provides discreet purchase, which has led to increasing volumes, said a @s…
#
# Date and Time of Tweet:-
# 2019-12-02 12:18:45
# RT @ETMarkets: What to do if you are among the victims of #KarvyBroking mess
#
# https://t.co/t98stWQM37 https://t.co/NU62w6C5vS
#
# Date and Time of Tweet:-
# 2019-12-02 12:18:12
# The contribution from your employer will be exempt up to 10% of basic salary + dearness allowance for deduction und… https://t.co/spxRtw2rlc
#
# Date and Time of Tweet:-
# 2019-12-02 12:15:00
# These long-pending projects, collectively worth over Rs 3.5 lakh crore, are either stuck or still meandering throug… https://t.co/dhGM7IR4aw
#
# Date and Time of Tweet:-
# 2019-12-02 12:00:00
# RT @ETDefence: #InPictures: Meet Lieutenant Shivangi, the first woman pilot for the #IndianNavy
#
# https://t.co/OxZdbI98vm
#
# Date and Time of Tweet:-
# 2019-12-02 11:55:09
# Former union minister and BJP MP Anantkumar Hegde has claimed his party colleague @Dev_Fadnavis was made CM in… https://t.co/UDIzOcUmLU
#
# Date and Time of Tweet:-
# 2019-12-02 11:45:00
# RT @ETMutualFunds: Many investors, especially new ones, are keen to invest directly in #mutualfunds . Here is a comprehensive list of artic…
#
# Date and Time of Tweet:-
# 2019-12-02 11:34:30
# In Pics | Thorough preparations pay off
#
# https://t.co/xIsRaVQg43
#
# Date and Time of Tweet:-
# 2019-12-02 11:30:00
# RT @ETDefence: #Insurgency in #Balochistan is likely to intensify as the current generation of young and dynamic leadership was now leading…
#
# Date and Time of Tweet:-
# 2019-12-02 11:20:42
# The candidates wearing such dresses or carrying metallic items will have to report at the designated centres at lea… https://t.co/UrPOpFQNv5
#
# Date and Time of Tweet:-
# 2019-12-02 11:15:00
# RT @ET_Wealth: Estate planning: Is there a way to ensure that #will is not challenged in #court of #law?
# #financialplanning #property
# https…
#
# Date and Time of Tweet:-
# 2019-12-02 11:09:30
# RT @ET_Wealth: Bad #credit #history? You can opt for a #PayDay #loan but read this first
# #Lending #loans #personalfinance
# https://t.co/tgaT…
#
# Date and Time of Tweet:-
# 2019-12-02 11:09:26
# At -50 degree Celsius the soldiers of the #IndianArmy posted at the base have to battle frostbite and icy winds. Wh… https://t.co/LKjZeY5sYC
#
# Date and Time of Tweet:-
# 2019-12-02 11:00:00
# The #TDP has of late been more proactive in responding to issues of the Hindu faith than its erstwhile ally #BJP, a… https://t.co/PcC1f1hjyP
#
# Date and Time of Tweet:-
# 2019-12-02 10:45:00
# A special court grants regular bail to businessman #RatulPuri in #AgustaWestland money laundering case https://t.co/gsZ7j7xSgG
#
# Date and Time of Tweet:-
# 2019-12-02 10:37:07
# In Pics | #Dog or wolf?
#
# https://t.co/pxAhhmLIhV
#
# Date and Time of Tweet:-
# 2019-12-02 10:30:00
# RT @ETMarkets: #BhartiAirtel, #VodafoneIdea and other telcos face as much as Rs 1.47 lakh crore in past liabilities following this ruling
# h…
#
# Date and Time of Tweet:-
# 2019-12-02 10:21:03
# RT @ET_RISE: .@WiJungle enables organizations to manage and secure their entire network through a single window. #cybersecurity https://t.c…
#
# Date and Time of Tweet:-
# 2019-12-02 10:20:55
# The Indian #economy is suffering through a major #slowdown, and one that shows no immediate sign of easing.
#
# https://t.co/HteUf2DyrP
#
# Date and Time of Tweet:-
# 2019-12-02 10:15:00
# RT @ETDefence: A recruitment drive by the #JammuAndKashmir police to fill about 5,200 posts of Special #Police Officers (#SPO) has evoked a…
#
# Date and Time of Tweet:-
# 2019-12-02 10:14:21
# #AyodhyaVerdict | A petition seeking review of the SC's November 9 judgement on #AyodhyaLandDispute by which the en… https://t.co/ucnFHZDDRQ
#
# Date and Time of Tweet:-
# 2019-12-02 10:06:49
# In Pics: Meet #LieutenantShivangi, the first woman pilot for the #IndianNavy https://t.co/dGR0vsXhni https://t.co/dvYtcGDzGS
#
# Date and Time of Tweet:-
# 2019-12-02 10:03:26
# Business conditions in the India’s manufacturing sector improved in November but firms shed #jobs for the first tim… https://t.co/Yfx1fJcyWq
#
# Date and Time of Tweet:-
# 2019-12-02 10:00:00
# RT @ETMarkets: #LIVE: #ClosingBell | Dec 2, 2019 https://t.co/Nr4RJ7PbcH
#
# Date and Time of Tweet:-
# 2019-12-02 09:54:38
# Ritesh Agarwal on #OYO roadmap, role of Aditya Ghosh | https://t.co/u3EF8LMOWT https://t.co/PA1PsGJ2YQ
#
# Date and Time of Tweet:-
# 2019-12-02 09:54:09
# In all of the recent history of deal making in India Inc, few names have had a higher intrigue factor than the one… https://t.co/5bnKYTXO0P
#
# Date and Time of Tweet:-
# 2019-12-02 09:47:09
# The lock-in period for #PPF account holder remains at 15 years irrespective of the age at which you open the accoun… https://t.co/nuUHLjQYQb
#
# Date and Time of Tweet:-
# 2019-12-02 09:45:00
# RT @ET_RISE: .@abchealthin will also offer covers such as heart secure, and accidental hospitalization, on the @MobiKwik platform. #fintech…
#
# Date and Time of Tweet:-
# 2019-12-02 09:37:19
# #Crimes against women: Change of mindset required to kill the social evil, says @MVenkaiahNaidu | Download the ET A… https://t.co/FV4eM6OuJI
#
# Date and Time of Tweet:-
# 2019-12-02 09:30:00
# [Sponsored] | From being home to mills, Wadala is now home to the office junta as well as the C-suite residers. Fin… https://t.co/WfWeSY3Xd3
#
# Date and Time of Tweet:-
# 2019-12-02 09:20:40
# The Centre is preparing a comprehensive database of #EconomicOffenders called the National Economic Offence Records… https://t.co/yzD9vkEevS
#
# Date and Time of Tweet:-
# 2019-12-02 09:15:00
# #Jio to introduce new 'all-in-one' plans with unlimited voice, #data from Dec 6 | Download the ET App:… https://t.co/6YKPkMW5Rk
#
# Date and Time of Tweet:-
# 2019-12-02 09:14:23
# Responding to a discussion during Zero Hour in the wake of the rape and murder of a veterinarian in #Hyderabad,… https://t.co/QZJgNCe9R9
#
# Date and Time of Tweet:-
# 2019-12-02 09:02:01
# The Sena also took a dim view of the objections raised by Fadnavis during the Maha Vikas Aghadi government's floor… https://t.co/gSvMgvTfbn
#
# Date and Time of Tweet:-
# 2019-12-02 09:00:00
# RT @ET_RISE: The products, indigenously manufactured under the @makeinindia &amp; @swachhbharat Scheme, have been dermatological tested and app…
#
# Date and Time of Tweet:-
# 2019-12-02 08:58:10
# RT @ET_RISE: The November 2019 collection is the third highest monthly collection since introduction of #GST, next only to April 2019 and M…
#
# Date and Time of Tweet:-
# 2019-12-02 08:58:05
# RT @ET_RISE: The shopkeepers are alleging @amazonIN and @Flipkart are circumventing the rules with predatory pricing and deep discounting.…
#
# Date and Time of Tweet:-
# 2019-12-02 08:58:00
# RT @ET_RISE: The appointment of @iamadityaghosh to the @oyorooms board also comes at a time when the seven year-old company has publicly be…
#
# Date and Time of Tweet:-
# 2019-12-02 08:57:53
# The House Select Committee on intelligence, who held a series of hearings in both public and closed door settings o… https://t.co/LDUxPgiHMU
#
# Date and Time of Tweet:-
# 2019-12-02 08:45:00
# #Oyo Hotels &amp; Homes has elevated its India and South Asia Head Aditya Ghosh to its board, and has named Rohit Kapoo… https://t.co/OW1okCDm0W
#
# Date and Time of Tweet:-
# 2019-12-02 08:43:27
# Representing about 70 million small #merchants who collectively control almost 90% of India’s retail trade, India’s… https://t.co/7tzKYzaMQY
#
# Date and Time of Tweet:-
# 2019-12-02 08:30:00
# #Breaking | Aditya Ghosh on #OYO board, Rohit Kapoor new India CEO. (IANS) https://t.co/HoVx2mkouv
#
# Date and Time of Tweet:-
# 2019-12-02 08:17:38
# The Delhi government has "strongly recommended" to reject the mercy petition filed by one of the 2012 #Nirbhaya mur… https://t.co/wEeDPUcuTA
#
# Date and Time of Tweet:-
# 2019-12-02 08:15:00
# #Maharashtra: Pankaja Munde removes #BJP from Twitter bio | https://t.co/zBgvLeChk9 https://t.co/mzPWSB0x9K
#
# Date and Time of Tweet:-
# 2019-12-02 08:00:00
# The #AirQuality index of the national capital read 250 at 4 pm on Sunday, up from Saturday's 193.
#
# https://t.co/u4iFSmkOLw
#
# Date and Time of Tweet:-
# 2019-12-02 07:45:00
# .@Dev_Fadnavis denies Hegde's claim about central funds, says never took any such decision | Download the ET App:… https://t.co/Rckfh6mjot
#
# Date and Time of Tweet:-
# 2019-12-02 07:44:00
# RT @ET_Wealth: How #IRDAI protects #policyholders from crises at #insurance companies
# #policy #cover #financialplanning
# https://t.co/psD8J…
#
# Date and Time of Tweet:-
# 2019-12-02 07:42:07
# .@Dev_Fadnavis took #oath to facilitate transfer of Rs 40,000cr to Centre: Anant Hegde, BJP leader |… https://t.co/EX8gEbKFHF
#
# Date and Time of Tweet:-
# 2019-12-02 07:41:33
# RT @ETDefence: None of the major ‘#MakeInIndia’ projects in the #defence arena, ranging from new-generation stealth #submarines, minesweepe…
#
# Date and Time of Tweet:-
# 2019-12-02 07:32:01
# RT @ETMutualFunds: #TopofMind | In this new series, we talk to mutual fund advisors and financial planners to find out what their clients a…
#
# Date and Time of Tweet:-
# 2019-12-02 07:31:52
# RT @ETMutualFunds: A series of downgrades and defaults have impaired the sentiment of investors in the debt mutual fund universe #mutualfun…
#
# Date and Time of Tweet:-
# 2019-12-02 07:31:44
# Seven Generals of the #Pakistan Army joined hands with Supreme Court chief justice Asif Saeed Khosa to block the… https://t.co/pUq55l7Tq3
#
# Date and Time of Tweet:-
# 2019-12-02 07:30:00
# #India and #Japan have agreed to add a new element to their growing defence partnership by holding joint fighter ai… https://t.co/iQ0idEJPtI
#
# Date and Time of Tweet:-
# 2019-12-02 07:15:00
# The ethics committee of the #LokSabha is likely to take up on Monday the issue of BJP member #PragyaThakur praising… https://t.co/1QQNizjoS0
#
# Date and Time of Tweet:-
# 2019-12-02 07:00:00
# .@myogiadityanath government in #UttarPradesh has identified 25 projects to be implemented at priority ahead of the… https://t.co/FKWsu9fvoY
#
# Date and Time of Tweet:-
# 2019-12-02 06:45:00
# Swedish King Carl XVI Gustaf, Queen Silvia arrive in Delhi | Download the ET App: https://t.co/byvyp6maip https://t.co/yOxzQDWJqu
#
# Date and Time of Tweet:-
# 2019-12-02 06:42:41
# RT @ET_Wealth: How #mutualfund #investments are taxed
# #tax #financialplanning #investors
# https://t.co/cmSoz2TopE
#
# Date and Time of Tweet:-
# 2019-12-02 06:34:39
# RT @ET_Wealth: These 7 #Companies with stable financials can be good #stock #investments
# #stockstowatch #stocks #investors
# https://t.co/tuV…
#
# Date and Time of Tweet:-
# 2019-12-02 06:34:33
# RT @ETDefence: Seven Generals of the #PakistanArmy joined hands with Supreme Court chief justice #AsifSaeedKhosa to block the Imran Khan go…
#
# Date and Time of Tweet:-
# 2019-12-02 06:32:08
# The Centre is likely to identify as many as eight articles as ‘single-use plastic’ items that will be discontinued… https://t.co/GDXkzGo6lm
#
# Date and Time of Tweet:-
# 2019-12-02 06:30:00
# Modi Govt always ready to help #industry: @AmitShah
#
# #ETAwards
#
# https://t.co/1kLxsubgGZ
#
# Date and Time of Tweet:-
# 2019-12-02 06:15:00
# Profile Name:-
# Economic Times
#
# Twitter ID:-
# EconomicTimes
#
# Bio:-
# India's No. 1 Business Daily that brings you the latest #news updates | A Times Internet Product
# https://t.co/1XskCMZXK5
#
# Location:-
#
#
# URL:-
# https://t.co/1azLywp9zh
#
# Joined:-
# 2009-05-13 12:54:58
#
# Following:-
# 43
#
# Followers:-
# 3366122
#
# Profile Image:-
# https://pbs.twimg.com/profile_images/1077844189893853184/PCBPSQVB_normal.jpg
#
# Coverpage:-
# https://pbs.twimg.com/profile_banners/39743812/1575253025
#
# Verification:-
# True

# %%
data={}
data={"Profile Name":tweet.user.name,
     "Twitter ID":tweet.user.screen_name,
     "Bio":tweet.user.description,
     "Location":tweet.user.location,
     "URL":tweet.user.url,
     "Joined":tweet.user.created_at,
     "Following":tweet.user.friends_count,
     "Followers":tweet.user.followers_count,
     "Profile Image":tweet.user.profile_image_url_https,
     "Coverpage":tweet.user.profile_banner_url,
     "Verification":tweet.user.verified,
     "tweet":tweet_data}
   
data
# Out:
# {'Profile Name': 'Economic Times',
#  'Twitter ID': 'EconomicTimes',
#  'Bio': "India's No. 1 Business Daily that brings you the latest #news updates | A Times Internet Product\nhttps://t.co/1XskCMZXK5",
#  'Location': '',
#  'URL': 'https://t.co/1azLywp9zh',
#  'Joined': datetime.datetime(2009, 5, 13, 12, 54, 58),
#  'Following': 43,
#  'Followers': 3366122,
#  'Profile Image': 'https://pbs.twimg.com/profile_images/1077844189893853184/PCBPSQVB_normal.jpg',
#  'Coverpage': 'https://pbs.twimg.com/profile_banners/39743812/1575253025',
#  'Verification': True,
#  'tweet': {0: {'text': 'Even with an announced tariff hike of 40%, #RelianceJio would be cheaper by 15-20% than other incumbents, analyst f… https://t.co/5Ol7dvPpCd',
#    'date': '2019-12-02 15:35:00',
#    'URL_ID': '1201525177772691456',
#    'Likes': 391,
#    'Retweet': 1,
#    'Hashtags': [{'text': 'RelianceJio', 'indices': [43, 55]}]},
#   1: {'text': '"Over 62 per cent or about $58 billion of the total loan advances ($93 billion) to Indian #RealEstate by banks and… https://t.co/sSDHQMl740',
#    'date': '2019-12-02 15:33:12',
#    'URL_ID': '1201524724020301825',
#    'Likes': 391,
#    'Retweet': 3,
#    'Hashtags': [{'text': 'RealEstate', 'indices': [90, 101]}]},
#   2: {'text': 'Justice Devan Ramachandran went hammer and tongs at the @vijayanpinarayi govt while taking up a contempt petition f… https://t.co/RZzuGGpL6F',
#    'date': '2019-12-02 15:32:15',
#    'URL_ID': '1201524488363360257',
#    'Likes': 391,
#    'Retweet': 1,
#    'Hashtags': []},
#   3: {'text': "#BJP MP Nishikant Dubey said in the Lok Sabha that #GDP has no relevance and it should not be treated as 'Bible, Ra… https://t.co/qP3Bhos8O1",
#    'date': '2019-12-02 15:30:59',
#    'URL_ID': '1201524166471512065',
#    'Likes': 391,
#    'Retweet': 0,
#    'Hashtags': [{'text': 'BJP', 'indices': [0, 4]},
#     {'text': 'GDP', 'indices': [51, 55]}]},
#   4: {'text': 'Refuting the claim, @Dev_Fadnavis said neither the Centre asked for any funds nor the #Maharashtra government sent… https://t.co/wYYWpPtwKs',
#    'date': '2019-12-02 15:30:00',
#    'URL_ID': '1201523919431159809',
#    'Likes': 391,
#    'Retweet': 4,
#    'Hashtags': [{'text': 'Maharashtra', 'indices': [86, 98]}]},
#   5: {'text': 'Gross direct tax collection increased by 5 per cent till November, Finance Minister #NirmalaSitharaman said on Mond… https://t.co/4zHz4neEFo',
#    'date': '2019-12-02 15:27:22',
#    'URL_ID': '1201523258622795777',
#    'Likes': 391,
#    'Retweet': 5,
#    'Hashtags': [{'text': 'NirmalaSitharaman', 'indices': [84, 102]}]},
#   6: {'text': "#ChandaKochhar had moved the Bombay High Court challenging #ICICIBank's decision to terminate her despite the bank… https://t.co/bTp5tt3bfS",
#    'date': '2019-12-02 15:25:33',
#    'URL_ID': '1201522798499254274',
#    'Likes': 391,
#    'Retweet': 1,
#    'Hashtags': [{'text': 'ChandaKochhar', 'indices': [0, 14]},
#     {'text': 'ICICIBank', 'indices': [59, 69]}]},
#   7: {'text': '"Madam we are neither anti national nor anti government. We want you to succeed big time as fastest growing economy… https://t.co/rkRTOf9On2',
#    'date': '2019-12-02 15:24:52',
#    'URL_ID': '1201522629963726848',
#    'Likes': 391,
#    'Retweet': 8,
#    'Hashtags': []},
#   8: {'text': 'RT @ET_Wealth: #Karvy Stock Broking #scandal: How #retail #investors can safeguard against such #frauds\n#karvystockbroking #karvyscam #safe…',
#    'date': '2019-12-02 15:23:33',
#    'URL_ID': '1201522296743051266',
#    'Likes': 391,
#    'Retweet': 2,
#    'Hashtags': [{'text': 'Karvy', 'indices': [15, 21]},
#     {'text': 'scandal', 'indices': [36, 44]},
#     {'text': 'retail', 'indices': [50, 57]},
#     {'text': 'investors', 'indices': [58, 68]},
#     {'text': 'frauds', 'indices': [96, 103]},
#     {'text': 'karvystockbroking', 'indices': [104, 122]},
#     {'text': 'karvyscam', 'indices': [123, 133]}]},
#   9: {'text': 'RT @ET_Wealth: #Compensation you get for #poorservice offered by insurers, #banks, #mutualfunds, #tax department\n#personalfinance #customer…',
#    'date': '2019-12-02 15:23:28',
#    'URL_ID': '1201522277226967040',
#    'Likes': 391,
#    'Retweet': 5,
#    'Hashtags': [{'text': 'Compensation', 'indices': [15, 28]},
#     {'text': 'poorservice', 'indices': [41, 53]},
#     {'text': 'banks', 'indices': [75, 81]},
#     {'text': 'mutualfunds', 'indices': [83, 95]},
#     {'text': 'tax', 'indices': [97, 101]},
#     {'text': 'personalfinance', 'indices': [113, 129]}]},
#   10: {'text': '"At present, there is no proposal to reduce #taxes on petrol and diesel," @nsitharaman said\n\nhttps://t.co/drAhklD8fV',
#    'date': '2019-12-02 15:15:00',
#    'URL_ID': '1201520144427540482',
#    'Likes': 391,
#    'Retweet': 1,
#    'Hashtags': [{'text': 'taxes', 'indices': [44, 50]}]},
#   11: {'text': '"The National Curriculum Framework (NCF), developed by the National Council of Education Research and Training (… https://t.co/swIiWHKQ8n',
#    'date': '2019-12-02 15:00:00',
#    'URL_ID': '1201516372506759169',
#    'Likes': 391,
#    'Retweet': 2,
#    'Hashtags': []},
#   12: {'text': '#India has been consistently increasing domestic production of #steel and is a net exporter in the current financia… https://t.co/8vKwoZy2El',
#    'date': '2019-12-02 14:45:00',
#    'URL_ID': '1201512594718281728',
#    'Likes': 391,
#    'Retweet': 4,
#    'Hashtags': [{'text': 'India', 'indices': [0, 6]},
#     {'text': 'steel', 'indices': [63, 69]}]},
#   13: {'text': 'Nearly 78 per cent depositors of the scam-hit #PMCBank have been allowed to withdraw their entire deposits even tho… https://t.co/qzBPMeNbKY',
#    'date': '2019-12-02 14:30:00',
#    'URL_ID': '1201508820712853504',
#    'Likes': 391,
#    'Retweet': 5,
#    'Hashtags': [{'text': 'PMCBank', 'indices': [46, 54]}]},
#   14: {'text': 'Total #motorcycle sales stood at 3,43,446 units, a marginal decline of 0.8 per cent, as compared to 3,46,544 units… https://t.co/2vhoIInAfv',
#    'date': '2019-12-02 14:15:00',
#    'URL_ID': '1201505044996050945',
#    'Likes': 391,
#    'Retweet': 5,
#    'Hashtags': [{'text': 'motorcycle', 'indices': [6, 17]}]},
#   15: {'text': 'Emerging #markets may need more than a surprise recovery in Chinese manufacturing to exorcise the pain of November.\n\nhttps://t.co/PRtjY9oub1',
#    'date': '2019-12-02 14:00:00',
#    'URL_ID': '1201501272169254912',
#    'Likes': 391,
#    'Retweet': 1,
#    'Hashtags': [{'text': 'markets', 'indices': [9, 17]}]},
#   16: {'text': "#Sebi's prompt action against #KarvyStockBroking has resulted in nearly 83,000 investors getting back their securit… https://t.co/hYTUqMI3x9",
#    'date': '2019-12-02 13:51:30',
#    'URL_ID': '1201499130167562241',
#    'Likes': 391,
#    'Retweet': 14,
#    'Hashtags': [{'text': 'Sebi', 'indices': [0, 5]},
#     {'text': 'KarvyStockBroking', 'indices': [30, 48]}]},
#   17: {'text': 'Uttar Pradesh govt recommended the selection of Zurich Airport International AG as the developer for the… https://t.co/Zaz9mmC9Dn',
#    'date': '2019-12-02 13:49:47',
#    'URL_ID': '1201498697940422656',
#    'Likes': 391,
#    'Retweet': 4,
#    'Hashtags': []},
#   18: {'text': "In a #SecurityBreach, seven unknown persons in a car drove up to the porch of Congress leader @priyankagandhi's Lod… https://t.co/z0xNEwgTRP",
#    'date': '2019-12-02 13:45:58',
#    'URL_ID': '1201497738682101761',
#    'Likes': 391,
#    'Retweet': 1,
#    'Hashtags': [{'text': 'SecurityBreach', 'indices': [5, 20]}]},
#   19: {'text': '"BJP govt at the Centre and the state are grabbing money from people of the country and filling pockets of 15 peopl… https://t.co/6ROGu6SLmV',
#    'date': '2019-12-02 13:45:00',
#    'URL_ID': '1201497495328694273',
#    'Likes': 391,
#    'Retweet': 6,
#    'Hashtags': []},
#   20: {'text': 'King, Queen of #Sweden meet PM #Modi, discuss ways to deepen ties https://t.co/Z17gQXFJYU https://t.co/Bt2g7A0Hxz',
#    'date': '2019-12-02 13:43:01',
#    'URL_ID': '1201496998127398915',
#    'Likes': 391,
#    'Retweet': 2,
#    'Hashtags': [{'text': 'Sweden', 'indices': [15, 22]},
#     {'text': 'Modi', 'indices': [31, 36]}]},
#   21: {'text': '.@asadowaisi corners govt on #economy, in Parliament | Download the ET App here: https://t.co/OpmgPJ3iU4 https://t.co/gMtHzQrMLr',
#    'date': '2019-12-02 13:42:33',
#    'URL_ID': '1201496879277568000',
#    'Likes': 391,
#    'Retweet': 96,
#    'Hashtags': [{'text': 'economy', 'indices': [29, 37]}]},
#   22: {'text': '‘#NDA is committed to save #BSNL’, says #NirmalaSitharaman in Parliament | Download the ET App here:… https://t.co/KZoAXRlAyV',
#    'date': '2019-12-02 13:37:21',
#    'URL_ID': '1201495571657191430',
#    'Likes': 391,
#    'Retweet': 0,
#    'Hashtags': [{'text': 'NDA', 'indices': [1, 5]},
#     {'text': 'BSNL', 'indices': [27, 32]},
#     {'text': 'NirmalaSitharaman', 'indices': [40, 58]}]},
#   23: {'text': '78% depositors of #PMCBank can withdraw their entire account balance: FM @nsitharaman  https://t.co/MHvj2tui7h https://t.co/MxJzQvDJab',
#    'date': '2019-12-02 13:34:12',
#    'URL_ID': '1201494778254221312',
#    'Likes': 391,
#    'Retweet': 14,
#    'Hashtags': [{'text': 'PMCBank', 'indices': [18, 26]}]},
#   24: {'text': "A consumer court in Maharashtra's Jalna district has ordered a state-run bus depot to pay Rs 5,000 as compensation… https://t.co/8wNSyDdBWm",
#    'date': '2019-12-02 13:30:00',
#    'URL_ID': '1201493720853409793',
#    'Likes': 391,
#    'Retweet': 10,
#    'Hashtags': []},
#   25: {'text': '#IndianRailways operating ratio of 98.44% worst in 10 years: #CAG https://t.co/2zovwcTgo9 https://t.co/BZSODNAZJk',
#    'date': '2019-12-02 13:28:21',
#    'URL_ID': '1201493304031903744',
#    'Likes': 391,
#    'Retweet': 7,
#    'Hashtags': [{'text': 'IndianRailways', 'indices': [0, 15]},
#     {'text': 'CAG', 'indices': [61, 65]}]},
#   26: {'text': 'Rapists should be lynched: #JayaBachchan in #RajyaSabha https://t.co/z3kUYnzmpE https://t.co/9uEh0QDOxR',
#    'date': '2019-12-02 13:26:52',
#    'URL_ID': '1201492931103711232',
#    'Likes': 391,
#    'Retweet': 12,
#    'Hashtags': [{'text': 'JayaBachchan', 'indices': [27, 40]},
#     {'text': 'RajyaSabha', 'indices': [44, 55]}]},
#   27: {'text': 'Swedish King, Queen accorded ceremonial reception at #RashtrapatiBhavan | Download the ET App here:… https://t.co/lsBevBWX27',
#    'date': '2019-12-02 13:25:37',
#    'URL_ID': '1201492616379944960',
#    'Likes': 391,
#    'Retweet': 1,
#    'Hashtags': [{'text': 'RashtrapatiBhavan', 'indices': [53, 71]}]},
#   28: {'text': 'RT @ET_RISE: .@Uber has a little over 1,000 employees providing critical regional and global customer support services to Uber riders, driv…',
#    'date': '2019-12-02 13:15:42',
#    'URL_ID': '1201490124715855873',
#    'Likes': 391,
#    'Retweet': 5,
#    'Hashtags': []},
#   29: {'text': 'As soon as the House met for the day, Speaker Om Birla said he would allow members to raise the "serious issue" in… https://t.co/5RP93tzrpJ',
#    'date': '2019-12-02 13:15:00',
#    'URL_ID': '1201489945300484097',
#    'Likes': 391,
#    'Retweet': 0,
#    'Hashtags': []},
#   30: {'text': 'RT @ET_Wealth: How long-term #investors should #deal with #market volatility\n#financialplanning #investments\nhttps://t.co/MoZkrRrdS8',
#    'date': '2019-12-02 13:12:56',
#    'URL_ID': '1201489425386987520',
#    'Likes': 391,
#    'Retweet': 1,
#    'Hashtags': [{'text': 'investors', 'indices': [29, 39]},
#     {'text': 'deal', 'indices': [47, 52]},
#     {'text': 'market', 'indices': [58, 65]},
#     {'text': 'financialplanning', 'indices': [77, 95]},
#     {'text': 'investments', 'indices': [96, 108]}]},
#   31: {'text': "#LeadStoryOnET | Traders want #Amazon, #Walmart to 'go back' https://t.co/NnGPnMr8so",
#    'date': '2019-12-02 13:11:11',
#    'URL_ID': '1201488985551302656',
#    'Likes': 391,
#    'Retweet': 3,
#    'Hashtags': [{'text': 'LeadStoryOnET', 'indices': [0, 14]},
#     {'text': 'Amazon', 'indices': [30, 37]},
#     {'text': 'Walmart', 'indices': [39, 47]}]},
#   32: {'text': "#LeadStoryOnET | Meet the Canadian billionaire who's putting money in @YESBANK https://t.co/nDKRBSABKh",
#    'date': '2019-12-02 13:10:24',
#    'URL_ID': '1201488790449086465',
#    'Likes': 391,
#    'Retweet': 4,
#    'Hashtags': [{'text': 'LeadStoryOnET', 'indices': [0, 14]}]},
#   33: {'text': "#LeadStoryOnET | Pay may go up in India, but there's a rider https://t.co/7iR2vU6cxR",
#    'date': '2019-12-02 13:09:46',
#    'URL_ID': '1201488631380111360',
#    'Likes': 391,
#    'Retweet': 2,
#    'Hashtags': [{'text': 'LeadStoryOnET', 'indices': [0, 14]}]},
#   34: {'text': 'Textile player #Raymond on Monday said ownership of Raymond brand will remain with the demerged new lifestyle compa… https://t.co/Q1iDHThevM',
#    'date': '2019-12-02 13:00:00',
#    'URL_ID': '1201486172410630144',
#    'Likes': 391,
#    'Retweet': 2,
#    'Hashtags': [{'text': 'Raymond', 'indices': [15, 23]}]},
#   35: {'text': 'Uttar Pradesh sugar mills have to provide fixed amounts of #molasses to #AlcoholicDrinks manufacturers at well belo… https://t.co/xnwYE6nRgB',
#    'date': '2019-12-02 12:45:00',
#    'URL_ID': '1201482395481858048',
#    'Likes': 391,
#    'Retweet': 6,
#    'Hashtags': [{'text': 'molasses', 'indices': [59, 68]},
#     {'text': 'AlcoholicDrinks', 'indices': [72, 88]}]},
#   36: {'text': 'RT @ETDefence: The #IslamicState has claimed responsibility for the #LondonBridgeAttack, saying the UK-born attacker, who wanted to set up…',
#    'date': '2019-12-02 12:35:30',
#    'URL_ID': '1201480006481768450',
#    'Likes': 391,
#    'Retweet': 7,
#    'Hashtags': [{'text': 'IslamicState', 'indices': [19, 32]},
#     {'text': 'LondonBridgeAttack', 'indices': [68, 87]}]},
#   37: {'text': 'In Pics | Low #tariff regime over\n\nhttps://t.co/KZYCUsc6NL',
#    'date': '2019-12-02 12:30:00',
#    'URL_ID': '1201478621946187778',
#    'Likes': 391,
#    'Retweet': 3,
#    'Hashtags': [{'text': 'tariff', 'indices': [14, 21]}]},
#   38: {'text': 'RT @ET_Wealth: #Money &amp; #Relationships: What are woman’s #Rights in a live-in arrangement?\n#FinancialPlanning #woman \nhttps://t.co/A093wBI6…',
#    'date': '2019-12-02 12:20:56',
#    'URL_ID': '1201476340622356480',
#    'Likes': 391,
#    'Retweet': 2,
#    'Hashtags': [{'text': 'Money', 'indices': [15, 21]},
#     {'text': 'Relationships', 'indices': [28, 42]},
#     {'text': 'Rights', 'indices': [61, 68]},
#     {'text': 'FinancialPlanning', 'indices': [95, 113]},
#     {'text': 'woman', 'indices': [114, 120]}]},
#   39: {'text': 'RT @ET_RISE: Online marketplaces have become a go-to place as it provides discreet purchase, which has led to increasing volumes, said a @s…',
#    'date': '2019-12-02 12:18:45',
#    'URL_ID': '1201475790447054849',
#    'Likes': 391,
#    'Retweet': 1,
#    'Hashtags': []},
#   40: {'text': 'RT @ETMarkets: What to do if you are among the victims of #KarvyBroking mess\n\nhttps://t.co/t98stWQM37 https://t.co/NU62w6C5vS',
#    'date': '2019-12-02 12:18:12',
#    'URL_ID': '1201475651917602817',
#    'Likes': 391,
#    'Retweet': 6,
#    'Hashtags': [{'text': 'KarvyBroking', 'indices': [58, 71]}]},
#   41: {'text': 'The contribution from your employer will be exempt up to 10% of basic salary + dearness allowance for deduction und… https://t.co/spxRtw2rlc',
#    'date': '2019-12-02 12:15:00',
#    'URL_ID': '1201474846187634689',
#    'Likes': 391,
#    'Retweet': 2,
#    'Hashtags': []},
#   42: {'text': 'These long-pending projects, collectively worth over Rs 3.5 lakh crore, are either stuck or still meandering throug… https://t.co/dhGM7IR4aw',
#    'date': '2019-12-02 12:00:00',
#    'URL_ID': '1201471073713315840',
#    'Likes': 391,
#    'Retweet': 6,
#    'Hashtags': []},
#   43: {'text': 'RT @ETDefence: #InPictures: Meet Lieutenant Shivangi, the first woman pilot for the #IndianNavy\n\nhttps://t.co/OxZdbI98vm',
#    'date': '2019-12-02 11:55:09',
#    'URL_ID': '1201469850251493376',
#    'Likes': 391,
#    'Retweet': 6,
#    'Hashtags': [{'text': 'InPictures', 'indices': [15, 26]},
#     {'text': 'IndianNavy', 'indices': [84, 95]}]},
#   44: {'text': 'Former union minister and BJP MP Anantkumar Hegde has claimed his party colleague @Dev_Fadnavis was made CM in… https://t.co/UDIzOcUmLU',
#    'date': '2019-12-02 11:45:00',
#    'URL_ID': '1201467295995846656',
#    'Likes': 391,
#    'Retweet': 8,
#    'Hashtags': []},
#   45: {'text': 'RT @ETMutualFunds: Many investors, especially new ones, are keen to invest directly in #mutualfunds . Here is a comprehensive list of artic…',
#    'date': '2019-12-02 11:34:30',
#    'URL_ID': '1201464653856985088',
#    'Likes': 391,
#    'Retweet': 1,
#    'Hashtags': [{'text': 'mutualfunds', 'indices': [87, 99]}]},
#   46: {'text': 'In Pics | Thorough preparations pay off\n\nhttps://t.co/xIsRaVQg43',
#    'date': '2019-12-02 11:30:00',
#    'URL_ID': '1201463521722195968',
#    'Likes': 391,
#    'Retweet': 2,
#    'Hashtags': []},
#   47: {'text': 'RT @ETDefence: #Insurgency in #Balochistan is likely to intensify as the current generation of young and dynamic leadership was now leading…',
#    'date': '2019-12-02 11:20:42',
#    'URL_ID': '1201461180050464768',
#    'Likes': 391,
#    'Retweet': 6,
#    'Hashtags': [{'text': 'Insurgency', 'indices': [15, 26]},
#     {'text': 'Balochistan', 'indices': [30, 42]}]},
#   48: {'text': 'The candidates wearing such dresses or carrying metallic items will have to report at the designated centres at lea… https://t.co/UrPOpFQNv5',
#    'date': '2019-12-02 11:15:00',
#    'URL_ID': '1201459746361892865',
#    'Likes': 391,
#    'Retweet': 2,
#    'Hashtags': []},
#   49: {'text': 'RT @ET_Wealth: Estate planning: Is there a way to ensure that #will is not challenged in #court of #law?\n#financialplanning #property\nhttps…',
#    'date': '2019-12-02 11:09:30',
#    'URL_ID': '1201458364233830401',
#    'Likes': 391,
#    'Retweet': 4,
#    'Hashtags': [{'text': 'will', 'indices': [62, 67]},
#     {'text': 'court', 'indices': [89, 95]},
#     {'text': 'law', 'indices': [99, 103]},
#     {'text': 'financialplanning', 'indices': [105, 123]},
#     {'text': 'property', 'indices': [124, 133]}]},
#   50: {'text': 'RT @ET_Wealth: Bad #credit #history? You can opt for a #PayDay #loan but read this first\n#Lending #loans #personalfinance\nhttps://t.co/tgaT…',
#    'date': '2019-12-02 11:09:26',
#    'URL_ID': '1201458345808252929',
#    'Likes': 391,
#    'Retweet': 2,
#    'Hashtags': [{'text': 'credit', 'indices': [19, 26]},
#     {'text': 'history', 'indices': [27, 35]},
#     {'text': 'PayDay', 'indices': [55, 62]},
#     {'text': 'loan', 'indices': [63, 68]},
#     {'text': 'Lending', 'indices': [89, 97]},
#     {'text': 'loans', 'indices': [98, 104]},
#     {'text': 'personalfinance', 'indices': [105, 121]}]},
#   51: {'text': 'At -50 degree Celsius the soldiers of the #IndianArmy posted at the base have to battle frostbite and icy winds. Wh… https://t.co/LKjZeY5sYC',
#    'date': '2019-12-02 11:00:00',
#    'URL_ID': '1201455974600458240',
#    'Likes': 391,
#    'Retweet': 7,
#    'Hashtags': [{'text': 'IndianArmy', 'indices': [42, 53]}]},
#   52: {'text': 'The #TDP has of late been more proactive in responding to issues of the Hindu faith than its erstwhile ally #BJP, a… https://t.co/PcC1f1hjyP',
#    'date': '2019-12-02 10:45:00',
#    'URL_ID': '1201452196493250560',
#    'Likes': 391,
#    'Retweet': 6,
#    'Hashtags': [{'text': 'TDP', 'indices': [4, 8]},
#     {'text': 'BJP', 'indices': [108, 112]}]},
#   53: {'text': 'A special court grants regular bail to businessman #RatulPuri in #AgustaWestland money laundering case https://t.co/gsZ7j7xSgG',
#    'date': '2019-12-02 10:37:07',
#    'URL_ID': '1201450215120621568',
#    'Likes': 391,
#    'Retweet': 3,
#    'Hashtags': [{'text': 'RatulPuri', 'indices': [51, 61]},
#     {'text': 'AgustaWestland', 'indices': [65, 80]}]},
#   54: {'text': 'In Pics | #Dog or wolf?\n\nhttps://t.co/pxAhhmLIhV',
#    'date': '2019-12-02 10:30:00',
#    'URL_ID': '1201448422290575362',
#    'Likes': 391,
#    'Retweet': 2,
#    'Hashtags': [{'text': 'Dog', 'indices': [10, 14]}]},
#   55: {'text': 'RT @ETMarkets: #BhartiAirtel, #VodafoneIdea and other telcos face as much as Rs 1.47 lakh crore in past liabilities following this ruling\nh…',
#    'date': '2019-12-02 10:21:03',
#    'URL_ID': '1201446172247740417',
#    'Likes': 391,
#    'Retweet': 1,
#    'Hashtags': [{'text': 'BhartiAirtel', 'indices': [15, 28]},
#     {'text': 'VodafoneIdea', 'indices': [30, 43]}]},
#   56: {'text': 'RT @ET_RISE: .@WiJungle enables organizations to manage and secure their entire network through a single window. #cybersecurity https://t.c…',
#    'date': '2019-12-02 10:20:55',
#    'URL_ID': '1201446135807660033',
#    'Likes': 391,
#    'Retweet': 2,
#    'Hashtags': [{'text': 'cybersecurity', 'indices': [113, 127]}]},
#   57: {'text': 'The Indian #economy is suffering through a major #slowdown, and one that shows no immediate sign of easing.\n\nhttps://t.co/HteUf2DyrP',
#    'date': '2019-12-02 10:15:00',
#    'URL_ID': '1201444646942982144',
#    'Likes': 391,
#    'Retweet': 5,
#    'Hashtags': [{'text': 'economy', 'indices': [11, 19]},
#     {'text': 'slowdown', 'indices': [49, 58]}]},
#   58: {'text': 'RT @ETDefence: A recruitment drive by the #JammuAndKashmir police to fill about 5,200 posts of Special #Police Officers (#SPO) has evoked a…',
#    'date': '2019-12-02 10:14:21',
#    'URL_ID': '1201444483419656192',
#    'Likes': 391,
#    'Retweet': 3,
#    'Hashtags': [{'text': 'JammuAndKashmir', 'indices': [42, 58]},
#     {'text': 'Police', 'indices': [103, 110]},
#     {'text': 'SPO', 'indices': [121, 125]}]},
#   59: {'text': "#AyodhyaVerdict | A petition seeking review of the SC's November 9 judgement on #AyodhyaLandDispute by which the en… https://t.co/ucnFHZDDRQ",
#    'date': '2019-12-02 10:06:49',
#    'URL_ID': '1201442589741727745',
#    'Likes': 391,
#    'Retweet': 4,
#    'Hashtags': [{'text': 'AyodhyaVerdict', 'indices': [0, 15]},
#     {'text': 'AyodhyaLandDispute', 'indices': [80, 99]}]},
#   60: {'text': 'In Pics: Meet #LieutenantShivangi, the first woman pilot for the #IndianNavy https://t.co/dGR0vsXhni https://t.co/dvYtcGDzGS',
#    'date': '2019-12-02 10:03:26',
#    'URL_ID': '1201441736385429504',
#    'Likes': 391,
#    'Retweet': 11,
#    'Hashtags': [{'text': 'LieutenantShivangi', 'indices': [14, 33]},
#     {'text': 'IndianNavy', 'indices': [65, 76]}]},
#   61: {'text': 'Business conditions in the India’s manufacturing sector improved in November but firms shed #jobs for the first tim… https://t.co/Yfx1fJcyWq',
#    'date': '2019-12-02 10:00:00',
#    'URL_ID': '1201440874632081408',
#    'Likes': 391,
#    'Retweet': 5,
#    'Hashtags': [{'text': 'jobs', 'indices': [92, 97]}]},
#   62: {'text': 'RT @ETMarkets: #LIVE: #ClosingBell | Dec 2, 2019 https://t.co/Nr4RJ7PbcH',
#    'date': '2019-12-02 09:54:38',
#    'URL_ID': '1201439523986530304',
#    'Likes': 391,
#    'Retweet': 1,
#    'Hashtags': [{'text': 'LIVE', 'indices': [15, 20]},
#     {'text': 'ClosingBell', 'indices': [22, 34]}]},
#   63: {'text': 'Ritesh Agarwal on #OYO roadmap, role of Aditya Ghosh | https://t.co/u3EF8LMOWT https://t.co/PA1PsGJ2YQ',
#    'date': '2019-12-02 09:54:09',
#    'URL_ID': '1201439400304865280',
#    'Likes': 391,
#    'Retweet': 1,
#    'Hashtags': [{'text': 'OYO', 'indices': [18, 22]}]},
#   64: {'text': 'In all of the recent history of deal making in India Inc, few names have had a higher intrigue factor than the one… https://t.co/5bnKYTXO0P',
#    'date': '2019-12-02 09:47:09',
#    'URL_ID': '1201437641054412800',
#    'Likes': 391,
#    'Retweet': 2,
#    'Hashtags': []},
#   65: {'text': 'The lock-in period for #PPF account holder remains at 15 years irrespective of the age at which you open the accoun… https://t.co/nuUHLjQYQb',
#    'date': '2019-12-02 09:45:00',
#    'URL_ID': '1201437097061519360',
#    'Likes': 391,
#    'Retweet': 5,
#    'Hashtags': [{'text': 'PPF', 'indices': [23, 27]}]},
#   66: {'text': 'RT @ET_RISE: .@abchealthin will also offer covers such as heart secure, and accidental hospitalization, on the @MobiKwik platform. #fintech…',
#    'date': '2019-12-02 09:37:19',
#    'URL_ID': '1201435164691156997',
#    'Likes': 391,
#    'Retweet': 1,
#    'Hashtags': [{'text': 'fintech', 'indices': [131, 139]}]},
#   67: {'text': '#Crimes against women: Change of mindset required to kill the social evil, says @MVenkaiahNaidu | Download the ET A… https://t.co/FV4eM6OuJI',
#    'date': '2019-12-02 09:30:00',
#    'URL_ID': '1201433323182153730',
#    'Likes': 391,
#    'Retweet': 9,
#    'Hashtags': [{'text': 'Crimes', 'indices': [0, 7]}]},
#   68: {'text': '[Sponsored] | From being home to mills, Wadala is now home to the office junta as well as the C-suite residers. Fin… https://t.co/WfWeSY3Xd3',
#    'date': '2019-12-02 09:20:40',
#    'URL_ID': '1201430972845084672',
#    'Likes': 391,
#    'Retweet': 3,
#    'Hashtags': []},
#   69: {'text': 'The Centre is preparing a comprehensive database of #EconomicOffenders called the National Economic Offence Records… https://t.co/yzD9vkEevS',
#    'date': '2019-12-02 09:15:00',
#    'URL_ID': '1201429547390001153',
#    'Likes': 391,
#    'Retweet': 9,
#    'Hashtags': [{'text': 'EconomicOffenders', 'indices': [52, 70]}]},
#   70: {'text': "#Jio to introduce new 'all-in-one' plans with unlimited voice, #data from Dec 6 | Download the ET App:… https://t.co/6YKPkMW5Rk",
#    'date': '2019-12-02 09:14:23',
#    'URL_ID': '1201429393177866241',
#    'Likes': 391,
#    'Retweet': 0,
#    'Hashtags': [{'text': 'Jio', 'indices': [0, 4]},
#     {'text': 'data', 'indices': [63, 68]}]},
#   71: {'text': 'Responding to a discussion during Zero Hour in the wake of the rape and murder of a veterinarian in #Hyderabad,… https://t.co/QZJgNCe9R9',
#    'date': '2019-12-02 09:02:01',
#    'URL_ID': '1201426279821500419',
#    'Likes': 391,
#    'Retweet': 3,
#    'Hashtags': [{'text': 'Hyderabad', 'indices': [100, 110]}]},
#   72: {'text': "The Sena also took a dim view of the objections raised by Fadnavis during the Maha Vikas Aghadi government's floor… https://t.co/gSvMgvTfbn",
#    'date': '2019-12-02 09:00:00',
#    'URL_ID': '1201425772935692288',
#    'Likes': 391,
#    'Retweet': 1,
#    'Hashtags': []},
#   73: {'text': 'RT @ET_RISE: The products, indigenously manufactured under the @makeinindia &amp; @swachhbharat Scheme, have been dermatological tested and app…',
#    'date': '2019-12-02 08:58:10',
#    'URL_ID': '1201425310320693248',
#    'Likes': 391,
#    'Retweet': 5,
#    'Hashtags': []},
#   74: {'text': 'RT @ET_RISE: The November 2019 collection is the third highest monthly collection since introduction of #GST, next only to April 2019 and M…',
#    'date': '2019-12-02 08:58:05',
#    'URL_ID': '1201425291513450497',
#    'Likes': 391,
#    'Retweet': 3,
#    'Hashtags': [{'text': 'GST', 'indices': [104, 108]}]},
#   75: {'text': 'RT @ET_RISE: The shopkeepers are alleging @amazonIN and @Flipkart are circumventing the rules with predatory pricing and deep discounting.…',
#    'date': '2019-12-02 08:58:00',
#    'URL_ID': '1201425268692242432',
#    'Likes': 391,
#    'Retweet': 2,
#    'Hashtags': []},
#   76: {'text': 'RT @ET_RISE: The appointment of @iamadityaghosh to the @oyorooms board also comes at a time when the seven year-old company has publicly be…',
#    'date': '2019-12-02 08:57:53',
#    'URL_ID': '1201425238858141696',
#    'Likes': 391,
#    'Retweet': 2,
#    'Hashtags': []},
#   77: {'text': 'The House Select Committee on intelligence, who held a series of hearings in both public and closed door settings o… https://t.co/LDUxPgiHMU',
#    'date': '2019-12-02 08:45:00',
#    'URL_ID': '1201421997684621312',
#    'Likes': 391,
#    'Retweet': 4,
#    'Hashtags': []},
#   78: {'text': '#Oyo Hotels &amp; Homes has elevated its India and South Asia Head Aditya Ghosh to its board, and has named Rohit Kapoo… https://t.co/OW1okCDm0W',
#    'date': '2019-12-02 08:43:27',
#    'URL_ID': '1201421607358435328',
#    'Likes': 391,
#    'Retweet': 9,
#    'Hashtags': [{'text': 'Oyo', 'indices': [0, 4]}]},
#   79: {'text': 'Representing about 70 million small #merchants who collectively control almost 90% of India’s retail trade, India’s… https://t.co/7tzKYzaMQY',
#    'date': '2019-12-02 08:30:00',
#    'URL_ID': '1201418223444463617',
#    'Likes': 391,
#    'Retweet': 10,
#    'Hashtags': [{'text': 'merchants', 'indices': [36, 46]}]},
#   80: {'text': '#Breaking | Aditya Ghosh on #OYO board, Rohit Kapoor new India CEO. (IANS) https://t.co/HoVx2mkouv',
#    'date': '2019-12-02 08:17:38',
#    'URL_ID': '1201415109777616897',
#    'Likes': 391,
#    'Retweet': 2,
#    'Hashtags': [{'text': 'Breaking', 'indices': [0, 9]},
#     {'text': 'OYO', 'indices': [28, 32]}]},
#   81: {'text': 'The Delhi government has "strongly recommended" to reject the mercy petition filed by one of the 2012 #Nirbhaya mur… https://t.co/wEeDPUcuTA',
#    'date': '2019-12-02 08:15:00',
#    'URL_ID': '1201414447941767168',
#    'Likes': 391,
#    'Retweet': 1,
#    'Hashtags': [{'text': 'Nirbhaya', 'indices': [102, 111]}]},
#   82: {'text': '#Maharashtra: Pankaja Munde removes #BJP from Twitter bio | https://t.co/zBgvLeChk9 https://t.co/mzPWSB0x9K',
#    'date': '2019-12-02 08:00:00',
#    'URL_ID': '1201410672854126592',
#    'Likes': 391,
#    'Retweet': 7,
#    'Hashtags': [{'text': 'Maharashtra', 'indices': [0, 12]},
#     {'text': 'BJP', 'indices': [36, 40]}]},
#   83: {'text': "The #AirQuality index of the national capital read 250 at 4 pm on Sunday, up from Saturday's 193.\n\nhttps://t.co/u4iFSmkOLw",
#    'date': '2019-12-02 07:45:00',
#    'URL_ID': '1201406897988894721',
#    'Likes': 391,
#    'Retweet': 2,
#    'Hashtags': [{'text': 'AirQuality', 'indices': [4, 15]}]},
#   84: {'text': ".@Dev_Fadnavis denies Hegde's claim about central funds, says never took any such decision | Download the ET App:… https://t.co/Rckfh6mjot",
#    'date': '2019-12-02 07:44:00',
#    'URL_ID': '1201406646020231168',
#    'Likes': 391,
#    'Retweet': 29,
#    'Hashtags': []},
#   85: {'text': 'RT @ET_Wealth: How #IRDAI protects #policyholders from crises at #insurance companies \n#policy #cover #financialplanning\nhttps://t.co/psD8J…',
#    'date': '2019-12-02 07:42:07',
#    'URL_ID': '1201406175566123009',
#    'Likes': 391,
#    'Retweet': 6,
#    'Hashtags': [{'text': 'IRDAI', 'indices': [19, 25]},
#     {'text': 'policyholders', 'indices': [35, 49]},
#     {'text': 'insurance', 'indices': [65, 75]},
#     {'text': 'policy', 'indices': [87, 94]},
#     {'text': 'cover', 'indices': [95, 101]},
#     {'text': 'financialplanning', 'indices': [102, 120]}]},
#   86: {'text': '.@Dev_Fadnavis took #oath to facilitate transfer of Rs 40,000cr to Centre: Anant Hegde, BJP leader |… https://t.co/EX8gEbKFHF',
#    'date': '2019-12-02 07:41:33',
#    'URL_ID': '1201406029411442688',
#    'Likes': 391,
#    'Retweet': 16,
#    'Hashtags': [{'text': 'oath', 'indices': [20, 25]}]},
#   87: {'text': 'RT @ETDefence: None of the major ‘#MakeInIndia’ projects in the #defence arena, ranging from new-generation stealth #submarines, minesweepe…',
#    'date': '2019-12-02 07:32:01',
#    'URL_ID': '1201403629875236865',
#    'Likes': 391,
#    'Retweet': 14,
#    'Hashtags': [{'text': 'MakeInIndia', 'indices': [34, 46]},
#     {'text': 'defence', 'indices': [64, 72]},
#     {'text': 'submarines', 'indices': [116, 127]}]},
#   88: {'text': 'RT @ETMutualFunds: #TopofMind | In this new series, we talk to mutual fund advisors and financial planners to find out what their clients a…',
#    'date': '2019-12-02 07:31:52',
#    'URL_ID': '1201403593279995904',
#    'Likes': 391,
#    'Retweet': 2,
#    'Hashtags': [{'text': 'TopofMind', 'indices': [19, 29]}]},
#   89: {'text': 'RT @ETMutualFunds: A series of downgrades and defaults have impaired the sentiment of investors in the debt mutual fund universe #mutualfun…',
#    'date': '2019-12-02 07:31:44',
#    'URL_ID': '1201403562154086401',
#    'Likes': 391,
#    'Retweet': 3,
#    'Hashtags': []},
#   90: {'text': 'Seven Generals of the #Pakistan Army joined hands with Supreme Court chief justice Asif Saeed Khosa to block the… https://t.co/pUq55l7Tq3',
#    'date': '2019-12-02 07:30:00',
#    'URL_ID': '1201403123647967233',
#    'Likes': 391,
#    'Retweet': 27,
#    'Hashtags': [{'text': 'Pakistan', 'indices': [22, 31]}]},
#   91: {'text': '#India and #Japan have agreed to add a new element to their growing defence partnership by holding joint fighter ai… https://t.co/iQ0idEJPtI',
#    'date': '2019-12-02 07:15:00',
#    'URL_ID': '1201399348233302016',
#    'Likes': 391,
#    'Retweet': 12,
#    'Hashtags': [{'text': 'India', 'indices': [0, 6]},
#     {'text': 'Japan', 'indices': [11, 17]}]},
#   92: {'text': 'The ethics committee of the #LokSabha is likely to take up on Monday the issue of BJP member #PragyaThakur praising… https://t.co/1QQNizjoS0',
#    'date': '2019-12-02 07:00:00',
#    'URL_ID': '1201395573749735425',
#    'Likes': 391,
#    'Retweet': 2,
#    'Hashtags': [{'text': 'LokSabha', 'indices': [28, 37]},
#     {'text': 'PragyaThakur', 'indices': [93, 106]}]},
#   93: {'text': '.@myogiadityanath government in #UttarPradesh has identified 25 projects to be implemented at priority ahead of the… https://t.co/FKWsu9fvoY',
#    'date': '2019-12-02 06:45:00',
#    'URL_ID': '1201391798565912576',
#    'Likes': 391,
#    'Retweet': 8,
#    'Hashtags': [{'text': 'UttarPradesh', 'indices': [32, 45]}]},
#   94: {'text': 'Swedish King Carl XVI Gustaf, Queen Silvia arrive in Delhi | Download the ET App: https://t.co/byvyp6maip https://t.co/yOxzQDWJqu',
#    'date': '2019-12-02 06:42:41',
#    'URL_ID': '1201391218288017409',
#    'Likes': 391,
#    'Retweet': 1,
#    'Hashtags': []},
#   95: {'text': 'RT @ET_Wealth: How #mutualfund #investments are taxed\n#tax #financialplanning #investors\nhttps://t.co/cmSoz2TopE',
#    'date': '2019-12-02 06:34:39',
#    'URL_ID': '1201389193441599488',
#    'Likes': 391,
#    'Retweet': 3,
#    'Hashtags': [{'text': 'mutualfund', 'indices': [19, 30]},
#     {'text': 'investments', 'indices': [31, 43]},
#     {'text': 'tax', 'indices': [54, 58]},
#     {'text': 'financialplanning', 'indices': [59, 77]},
#     {'text': 'investors', 'indices': [78, 88]}]},
#   96: {'text': 'RT @ET_Wealth: These 7 #Companies with stable financials can be good #stock #investments\n#stockstowatch #stocks #investors\nhttps://t.co/tuV…',
#    'date': '2019-12-02 06:34:33',
#    'URL_ID': '1201389168409993216',
#    'Likes': 391,
#    'Retweet': 1,
#    'Hashtags': [{'text': 'Companies', 'indices': [23, 33]},
#     {'text': 'stock', 'indices': [69, 75]},
#     {'text': 'investments', 'indices': [76, 88]},
#     {'text': 'stockstowatch', 'indices': [89, 103]},
#     {'text': 'stocks', 'indices': [104, 111]},
#     {'text': 'investors', 'indices': [112, 122]}]},
#   97: {'text': 'RT @ETDefence: Seven Generals of the #PakistanArmy joined hands with Supreme Court chief justice #AsifSaeedKhosa to block the Imran Khan go…',
#    'date': '2019-12-02 06:32:08',
#    'URL_ID': '1201388561297072129',
#    'Likes': 391,
#    'Retweet': 9,
#    'Hashtags': [{'text': 'PakistanArmy', 'indices': [37, 50]},
#     {'text': 'AsifSaeedKhosa', 'indices': [97, 112]}]},
#   98: {'text': 'The Centre is likely to identify as many as eight articles as ‘single-use plastic’ items that will be discontinued… https://t.co/GDXkzGo6lm',
#    'date': '2019-12-02 06:30:00',
#    'URL_ID': '1201388024182919170',
#    'Likes': 391,
#    'Retweet': 10,
#    'Hashtags': []},
#   99: {'text': 'Modi Govt always ready to help #industry: @AmitShah\n\n#ETAwards\n\nhttps://t.co/1kLxsubgGZ',
#    'date': '2019-12-02 06:15:00',
#    'URL_ID': '1201384248957124609',
#    'Likes': 391,
#    'Retweet': 1,
#    'Hashtags': [{'text': 'industry', 'indices': [31, 40]},
#     {'text': 'ETAwards', 'indices': [53, 62]}]}}}

# %%
data_json = json.dumps(data, indent=4, default=str)

# %%
data_json
# Out:
# '{\n    "Profile Name": "Economic Times",\n    "Twitter ID": "EconomicTimes",\n    "Bio": "India\'s No. 1 Business Daily that brings you the latest #news updates | A Times Internet Product\\nhttps://t.co/1XskCMZXK5",\n    "Location": "",\n    "URL": "https://t.co/1azLywp9zh",\n    "Joined": "2009-05-13 12:54:58",\n    "Following": 43,\n    "Followers": 3366122,\n    "Profile Image": "https://pbs.twimg.com/profile_images/1077844189893853184/PCBPSQVB_normal.jpg",\n    "Coverpage": "https://pbs.twimg.com/profile_banners/39743812/1575253025",\n    "Verification": true,\n    "tweet": {\n        "0": {\n            "text": "Even with an announced tariff hike of 40%, #RelianceJio would be cheaper by 15-20% than other incumbents, analyst f\\u2026 https://t.co/5Ol7dvPpCd",\n            "date": "2019-12-02 15:35:00",\n            "URL_ID": "1201525177772691456",\n            "Likes": 391,\n            "Retweet": 1,\n            "Hashtags": [\n                {\n                    "text": "RelianceJio",\n                    "indices": [\n                        43,\n                        55\n                    ]\n                }\n            ]\n        },\n        "1": {\n            "text": "\\"Over 62 per cent or about $58 billion of the total loan advances ($93 billion) to Indian #RealEstate by banks and\\u2026 https://t.co/sSDHQMl740",\n            "date": "2019-12-02 15:33:12",\n            "URL_ID": "1201524724020301825",\n            "Likes": 391,\n            "Retweet": 3,\n            "Hashtags": [\n                {\n                    "text": "RealEstate",\n                    "indices": [\n                        90,\n                        101\n                    ]\n                }\n            ]\n        },\n        "2": {\n            "text": "Justice Devan Ramachandran went hammer and tongs at the @vijayanpinarayi govt while taking up a contempt petition f\\u2026 https://t.co/RZzuGGpL6F",\n            "date": "2019-12-02 15:32:15",\n            "URL_ID": "1201524488363360257",\n            "Likes": 391,\n            "Retweet": 1,\n            "Hashtags": []\n        },\n        "3": {\n            "text": "#BJP MP Nishikant Dubey said in the Lok Sabha that #GDP has no relevance and it should not be treated as \'Bible, Ra\\u2026 https://t.co/qP3Bhos8O1",\n            "date": "2019-12-02 15:30:59",\n            "URL_ID": "1201524166471512065",\n            "Likes": 391,\n            "Retweet": 0,\n            "Hashtags": [\n                {\n                    "text": "BJP",\n                    "indices": [\n                        0,\n                        4\n                    ]\n                },\n                {\n                    "text": "GDP",\n                    "indices": [\n                        51,\n                        55\n                    ]\n                }\n            ]\n        },\n        "4": {\n            "text": "Refuting the claim, @Dev_Fadnavis said neither the Centre asked for any funds nor the #Maharashtra government sent\\u2026 https://t.co/wYYWpPtwKs",\n            "date": "2019-12-02 15:30:00",\n            "URL_ID": "1201523919431159809",\n            "Likes": 391,\n            "Retweet": 4,\n            "Hashtags": [\n                {\n                    "text": "Maharashtra",\n                    "indices": [\n                        86,\n                        98\n                    ]\n                }\n            ]\n        },\n        "5": {\n            "text": "Gross direct tax collection increased by 5 per cent till November, Finance Minister #NirmalaSitharaman said on Mond\\u2026 https://t.co/4zHz4neEFo",\n            "date": "2019-12-02 15:27:22",\n            "URL_ID": "1201523258622795777",\n            "Likes": 391,\n            "Retweet": 5,\n            "Hashtags": [\n                {\n                    "text": "NirmalaSitharaman",\n                    "indices": [\n                        84,\n                        102\n                  ...

# %%
import os
json = open("Twitter_json_data.json",'w')
json.write(data_json)
json.close()
